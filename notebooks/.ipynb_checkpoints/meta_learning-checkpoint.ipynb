# %%
import numpy as np
import torch
from torch import nn
import torch.functional as F
import matplotlib as mpl
import matplotlib.pyplot as plt
from tqdm import tqdm
from torch.autograd import Variable


import matplotlib.pylab as pylab

plt.style.use("science") # requires SciencePlots
params = {'legend.fontsize': 27,
          'figure.figsize': (10, 10),
         'axes.labelsize': 27,
         'axes.titlesize': 30,
         'xtick.labelsize':30,
         'ytick.labelsize':30,
         'figure.titlesize': 40,
          'xtick.major.size': 8,
          'xtick.minor.size': 4,
         'xtick.major.width': 1,
          'xtick.minor.width': 1,
         'ytick.major.size': 8,
          'ytick.minor.size': 4,
         'ytick.major.width': 1,
          'ytick.minor.width': 1,

         }
pylab.rcParams.update(params)
mpl.rcParams['text.latex.preamble'] = r'\usepackage{amsfonts}' #for \mathbb command

# %%
def f(x):
    return np.sin(5*x + np.pi/2)

class SineWaveTask:
    def __init__(self, w=1):
        self.w = w
        self.train_x = None
        
    def training_set(self, size=10, a=None, force_new=False):
        if a is None:
            _a = np.random.uniform(-5, 5)
        else:
            _a = a
        if self.train_x is None and not force_new:
            self.train_x = np.random.uniform(_a, _a + self.w, size)
            x = self.train_x
        elif not force_new:
            x = self.train_x
        else:
            self.train_x = np.random.uniform(_a, _a + self.w, size)
        y = f(x)
        return torch.Tensor(x), torch.Tensor(y)
    
    def test_set(self, size=50):
        _a = np.random.uniform(-5, 5)
        x = np.linspace(_a, _a + self.w, size)
        y = f(x)
        return torch.Tensor(x), torch.Tensor(y)
    
    def plot(self, *args, **kwargs):
        x, y = self.test_set(size=100)
        return plt.plot(x.numpy(), y.numpy(), *args, **kwargs)

# %%
A = -2
W = 4
D = SineWaveTask(w=W).training_set(size=100, a=A)
x_train, y_train = D
plt.plot(x_train, y_train, "k.")
plt.xlabel(r"$x$")
plt.ylabel(r"$f(x)$")
plt.title(r"Ensemble d'entraînement $\mathcal{D}$");

# %% [markdown]
# # Régression traditionnelle

# %%
class MLP(nn.Module):
    '''
    Multilayer Perceptron.
    '''
    def __init__(self, p=5, h=16):
        super().__init__()
        self.p = p
        self.l1 = nn.Linear(p, h)
        self.l2 = nn.Linear(h, h)
        self.l3 = nn.Linear(h, 1)
        self.nl = nn.ELU()
    
    def forward(self, x):
        '''Forward pass'''
        x = torch.stack([x**(i+1) for i in range(self.p)], dim=1)
        x = self.nl(self.l1(x))
        x = self.nl(self.l2(x))
        x = self.l3(x)
        return x.squeeze()

P = 6
STEPS = 5000
loss_ps = [[] for i in range(P)]
models = []
for p in tqdm(range(1, P)):
    model = MLP(p=p)
    models.append(model)
    optim = torch.optim.Adam(model.parameters(), lr=1e-3)
    for i in range(STEPS):
        optim.zero_grad()
        loss = torch.mean((model.forward(x_train) - y_train)**2)
        loss.backward()
        optim.step()
        loss_ps[p-1].append(loss.item())
# Out:
# 100%|██████████| 5/5 [00:12<00:00,  2.59s/it]

# %%
cmap = mpl.cm.get_cmap('jet', P-1)
norm = mpl.colors.Normalize(vmin=1, vmax=P)
fig = plt.figure()

for p in tqdm(range(1, P)):
    plt.plot(loss_ps[p-1], color=cmap(norm(p)), lw=3)

plt.title(r"$\mathbf{x} = \bigoplus_{p=1}^P x^p  $")
plt.xlabel("Itérations", labelpad=10)
plt.ylabel(r"$\mathbb{E}_{(\mathbf{x}, y) \sim \mathcal{D}} \bigg[\big(f_{\theta}(\mathbf{x}) - y\big)^2\bigg]$", labelpad=10)
plt.xlim(0, 1000)
cmap = mpl.cm.ScalarMappable(norm=norm, cmap=cmap)
cmap.set_array([])
formatter = plt.FuncFormatter(lambda val, loc: int(val-0.5))
cb = fig.colorbar(cmap, ticks=[i+0.5 for i in range(1, P)], pad=0.01, format=formatter)
cb.set_label("P", labelpad=10)
cb.ax.minorticks_off()

# plt.savefig("../figures/reg_learning_curves.png")
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 323.22it/s]

# %%
model = models[0]

# %%
x_support = torch.linspace(-5, 5, 1000)
y_true = f(x_support)

y_pred = model(x_support).detach().cpu()
plt.plot(x_support, y_true, "k-", lw=4, label=r"$f(x) = \sin(5x + \frac{\pi}{2})$")
plt.plot(x_support, y_pred, "r--", lw=3, label=r"$f_{\theta^\star}(x)$")

plt.axvspan(-5, A, color="k", alpha=0.3)
plt.axvspan(-A, 5, color="k", alpha=0.3)
plt.axvspan(-W/2, W/2, color="b", alpha=0.3)
plt.annotate(r"$\mathcal{D}$", xy=(0, 2), fontsize=25, ha='center')
plt.annotate(r"$\mathcal{D}^{\mathrm{test}}$", xy=(-4, 2), fontsize=25, ha='center')
plt.annotate(r"$\mathcal{D}^{\mathrm{test}}$", xy=(4, 2), fontsize=25, ha='center')


plt.xlim(-5, 5)
plt.ylim(-2.5, 2.5)
plt.xlabel(r"$x$")
plt.ylabel(r"$f(x)$")

plt.legend(loc=3, frameon=True)
plt.savefig("../figures/regression_exemple.png")

# %%
A = -2
W = 4
partitions = 3
Ds = []

cmap = mpl.cm.get_cmap('brg', partitions)
norm = mpl.colors.Normalize(vmin=0, vmax=partitions)
for p in range(partitions):
    Ds.append(SineWaveTask(w=W/partitions).training_set(size=100 // partitions, a=A + p*W/3)) # Make sure we're not adding samples for fair comparison
    plt.plot(*Ds[-1], ".", color=cmap(norm(p)), label=r"$\mathcal{D}^{(%d)}$" % p, markersize=10)
plt.legend(frameon=True)
plt.xlabel(r"$x$")
plt.ylabel(r"$f(x)$")
# Out:
# Text(0, 0.5, '$f(x)$')

# %%
def detach_var(v):
    var = Variable(v.data, requires_grad=True)
    var.retain_grad()
    return var

def detach_param(v):
    return nn.Parameter(v.data)

def preprocess_grad(x, p=10.):
    # pre-processing according to Deepmind 'Learning to Learn' paper
    threshold = torch.exp(-x)

    x_abs = torch.abs(x)
    is_higher = x_abs >= threshold

    processed_x = [torch.zeros_like(x), torch.zeros_like(x)]
    processed_x[0][is_higher] = torch.log(x_abs[is_higher] + 1e-8) / p
    processed_x[1][is_higher] = torch.sign(x[is_higher])
    processed_x[0][~is_higher] = -1.
    processed_x[1][~is_higher] = x[~is_higher] * np.exp(p)
    processed_x = torch.concat(processed_x, dim=1)
    return processed_x


class MLPNet(nn.Module):
    def __init__(self, named_parameters={}, p=1, h=16):
        self.p = p
#         self.layers = nn.Sequential(
#           nn.Linear(p, h),
#           nn.ELU(),
#           nn.Linear(h, h),
#           nn.ELU(),
#           nn.Linear(h, 1)
#         )     
        # Sadly this network needs to be implemented without using the convenient pytorch
        # abstractions such as nn.Linear, because afaik there is no way to load parameters
        # in those in a way that preserves gradients. So we write them with matmul operation explicitly here
        super().__init__()

        if named_parameters != {}:
            self.params = named_parameters
        else:
            self.params = {}
            self.params[f'layer.0.weight'] = nn.Parameter(torch.randn(p, h) * 0.3)
            self.params[f'layer.0.bias'] = nn.Parameter(torch.zeros(h))
#             self.params[f'layer.1.weight'] = nn.Parameter(torch.randn(h, h) * 0.3)
#             self.params[f'layer.1.bias'] = nn.Parameter(torch.zeros(h))
            self.params[f'layer.2.weight'] = nn.Parameter(torch.randn(h, 1) * 0.3)
            self.params[f'layer.2.bias'] = nn.Parameter(torch.zeros(1))
            
        self.activation = torch.sin
                
    def named_parameters(self):
        return [(k, v) for k, v in self.params.items()]
    
    def forward(self, x):
        out = torch.stack([x**(i+1) for i in range(self.p)], dim=1)
        out =  torch.matmul(out, self.params[f'layer.0.weight']) + self.params[f'layer.0.bias']
#         out =  self.activation(torch.matmul(out, self.params[f'layer.1.weight']) + self.params[f'layer.1.bias'])
        out =  self.activation(torch.matmul(out, self.params[f'layer.2.weight']) + self.params[f'layer.2.bias'])
        return out


class LSTMOptNet(nn.Module):
    def __init__(self, out_scale=0.1, h=20):
        super(LSTMOptNet, self).__init__()
        self.h = h
        self.l1 = nn.LSTMCell(1, h)
        self.l2 = nn.LSTMCell(h, h)
        self.lout = nn.Linear(h, 1)
        self.out_scale = out_scale
        
    def reset_states(self, model):
        self.h_n1 = {}
        self.h_n2 = {}
        self.c_n1 = {}
        self.c_n2 = {}
        for key, params in model.named_parameters():
            self.h_n1[key] = torch.zeros(params.view(-1).shape[0], self.h)
            self.h_n2[key] = torch.zeros(params.view(-1).shape[0], self.h)
            self.c_n1[key] = torch.zeros(params.view(-1).shape[0], self.h)
            self.c_n2[key] = torch.zeros(params.view(-1).shape[0], self.h)

    def forward(self, x, key):
        h1 = self.h_n1[key]
        h2 = self.h_n2[key]
        c1 = self.c_n1[key]
        c2 = self.c_n2[key]
        
#         x = preprocess_grad(x)
        h1, c1 = self.l1(x, (h1, c1))
        h2, c2 = self.l2(h1, (h2, c2))
        g = self.lout(h2)
        
        self.h_n1[key] = h1
        self.h_n2[key] = h2
        self.c_n1[key] = c1
        self.c_n2[key] = c2
        return g * self.out_scale



OUTER_STEPS = 50
INNER_STEPS = 20
H = 16
H_meta = 20
OUT_SCALE = 1.0
P = 1
optnet = LSTMOptNet(out_scale=OUT_SCALE, h=H_meta)
meta_opt = torch.optim.Adam(optnet.parameters(), lr=1e-2)
train_losses = []
meta_losses = []

for i in tqdm(range(OUTER_STEPS)):
    # Prepare cross-validation partitions of training set
    training_partition = np.random.randint(0, partitions)
    test_partitions = list(set(range(partitions)).difference(set({training_partition})))
    x_train, y_train = [Variable(_x) for _x in Ds[training_partition]] # make sure we can differentiate through training set
    x_val, y_val = torch.concat([Ds[_i][0] for _i in test_partitions]), torch.concat([Ds[_i][0] for _i in test_partitions])
    # randomly instantiate a network
    result_params = {}
    model = MLPNet(h=H, p=P)
    optnet.reset_states(model)
    meta_loss = torch.zeros(1)
    # Inner optimization of f_theta by g_varphi
    for j in range(INNER_STEPS):
        inner_loss = torch.mean((model.forward(x_train) - y_train)**2)
        inner_loss.backward(retain_graph=True)
        for key, p in model.named_parameters():
            grads = detach_var(p.grad.view(-1, 1))
            grads = optnet(grads, key)
            result_params[key] = p + grads.view(*p.shape)
            result_params[key].retain_grad()
            # update network parametrs inplace cannot be used, because pytorch does allow gradient to flow through this op
            # p.data.copy_(result_params[key])
        # instead, we create a new instance of model, with the result_params
        model = MLPNet(result_params, p=P)
        # Collect cross validation loss with updated params
#         meta_loss += torch.mean((model.forward(x_train) - y_train)**2)
        meta_loss += torch.mean((model.forward(x_val) - y_val)**2)
    # Meta update of g_varphi
    meta_opt.zero_grad()
    meta_loss /= INNER_STEPS
    meta_loss.backward()
    meta_opt.step()

    # logs
    meta_losses.append(meta_loss.item())
    train_losses.append(inner_loss.item())
# Out:
# 100%|██████████| 50/50 [00:19<00:00,  2.56it/s]

# %%
plt.plot(train_losses, label="Train")
plt.plot(meta_losses, label="Méta")
plt.legend(frameon=True)
plt.ylim(0, 1)
# plt.xlim(0, 20)
# Out:
# (0.0, 1.0)

# %%
x_support = torch.linspace(-5, 5, 1000)
y_true = f(x_support)

# use D train to learn model
x_train, y_train = D
result_params = {}
model = MLPNet(h=H)
optnet.reset_states(model)
for j in range(INNER_STEPS):
    inner_loss = torch.mean((model.forward(x_train) - y_train)**2)
    inner_loss.backward(retain_graph=True)
    for key, p in model.named_parameters():
        grads = detach_var(p.grad.view(-1, 1))
        grads = optnet(grads, key)
        result_params[key] = p + grads.view(*p.shape)
        result_params[key].retain_grad()
    model = MLPNet(result_params)
# Make prediction with learned network
y_pred = model(x_support).detach().cpu()
plt.plot(x_support, y_true, "k-", lw=4, label=r"$f(x) = \sin(5x + \frac{\pi}{2})$")
plt.plot(x_support, y_pred, "r--", lw=3, label=r"$f_{\theta^\star}(x)$")

plt.axvspan(-5, A, color="k", alpha=0.3)
plt.axvspan(-A, 5, color="k", alpha=0.3)
plt.axvspan(-W/2, W/2, color="b", alpha=0.3)
plt.annotate(r"$\mathcal{D}$", xy=(0, 2), fontsize=25, ha='center')
plt.annotate(r"$\mathcal{D}^{\mathrm{test}}$", xy=(-4, 2), fontsize=25, ha='center')
plt.annotate(r"$\mathcal{D}^{\mathrm{test}}$", xy=(4, 2), fontsize=25, ha='center')

plt.xlim(-5, 5)
# plt.ylim(-2.5, 2.5)
plt.xlabel(r"$x$")
plt.ylabel(r"$f(x)$")

plt.legend(loc=3, frameon=True)
